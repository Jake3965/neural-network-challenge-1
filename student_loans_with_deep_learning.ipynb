# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"]

# Define the features set X by dropping the credit_ranking column
X = loans_df.drop(columns=["credit_ranking"])

# Display the first few rows of X
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop(columns=["credit_ranking"])

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_train_scaled = scaler.fit_transform(X_train)

# Scale the features testing dataset
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the number of inputs (features) to the model
number_of_features = X_train_scaled.shape[1]

# Review the number of features
number_of_features
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 = 2 * number_of_features

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = number_of_features

# Define the number of neurons in the output layer (binary classification)
output_neurons = 1

# %%
from tensorflow.keras import Input

# Create the Sequential model instance
model = Sequential()

# Add an input layer
model.add(Input(shape=(number_of_features,)))

# Add the first hidden layer
model.add(Dense(units=hidden_nodes_layer1, activation="relu"))

# Add the second hidden layer
model.add(Dense(units=hidden_nodes_layer2, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
model.add(Dense(units=output_neurons, activation="sigmoid"))

# %%
# Display the Sequential model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 22)                  │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 11)                  │             253 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              12 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 529 (2.07 KB)
#  Trainable params: 529 (2.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# %%
# Fit the model using 50 epochs and the training data
history = model.fit(
    X_train_scaled,
    y_train,
    epochs=50,
    batch_size=32,
    verbose=1,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.4070 - loss: 0.8580 - val_accuracy: 0.4727 - val_loss: 0.7412
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4845 - loss: 0.7315 - val_accuracy: 0.6172 - val_loss: 0.6634
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6070 - loss: 0.6594 - val_accuracy: 0.7070 - val_loss: 0.6096
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6809 - loss: 0.6098 - val_accuracy: 0.7422 - val_loss: 0.5707
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7226 - loss: 0.5619 - val_accuracy: 0.7422 - val_loss: 0.5434
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7367 - loss: 0.5475 - val_accuracy: 0.7383 - val_loss: 0.5297
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7483 - loss: 0.5291 - val_accuracy: 0.7500 - val_loss: 0.5203
# Epoch 8/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=1)

# Display the model loss and accuracy results
print(f"Loss: {loss}, Accuracy: {accuracy}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7624 - loss: 0.4975
# Loss: 0.5357598662376404, Accuracy: 0.7250000238418579

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Save and export the model to a keras file
model.save("student_loans.keras")

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
model_file_path = "student_loans.keras"

# Load the model to a new object
loaded_model = tf.keras.models.load_model(model_file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = loaded_model.predict(X_test_scaled)

# Convert predictions to binary values (0 or 1) based on a threshold of 0.5
binary_predictions = [1 if pred > 0.5 else 0 for pred in predictions]

# Create a DataFrame to store predictions
predictions_df = pd.DataFrame({
    "Predicted": binary_predictions,
    "Actual": y_test.values
})

# Display a sample of the predictions
predictions_df.head()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Predicted  Actual
# 0          0       0
# 1          0       1
# 2          1       1
# 3          1       1
# 4          1       1

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame({
    "Predicted": binary_predictions,
    "Actual": y_test.values
})

# Display a sample of the predictions DataFrame
predictions_df.head()
# Out:
#    Predicted  Actual
# 0          0       0
# 1          0       1
# 2          1       1
# 3          1       1
# 4          1       1

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, binary_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.73      0.72       154
#            1       0.74      0.72      0.73       166
#
#     accuracy                           0.72       320
#    macro avg       0.73      0.73      0.72       320
# weighted avg       0.73      0.72      0.73       320

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1.For building a system to help students find loans, here's what I think we'd need:
# First up, you'd definitely need to know basic stuff about the students:
#
# How much money their family makes and where they live.
# Whether they're living on campus or commuting.
# If they have a part-time job.
#
# And then for the loans themselves, you'd want:
#
# How much money they need.
# When they think they can start paying it back.
# Their credit score (or their parents' if they're cosigning).
# What their major is (cause let's be real, some majors make more money after graduation).
#
# From what I've seen with my own student loans, you'd also want to look at:
#
# Different banks' interest rates.
# Which loans let you wait till after graduation to start paying.
# If they offer any perks for good grades.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# The recommendation system would primarily use content-based filtering:
#
# The features collected (e.g., demographics, academic data, financial data) are specific to individual students and loan products.
#
# Content-based filtering is appropriate because it focuses on matching user attributes with loan options based on the data collected rather than relying on patterns from other users.
#
# Alternatively, context-based filtering could also be implemented by incorporating situational factors, such as current economic conditions or regional loan trends, which affect loan availability and suitability.**
#
#
# **3.  Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.
# Data Privacy and Security:
#
# Handling sensitive financial and academic data poses privacy risks. Ensuring compliance with data protection laws (e.g., GDPR, FERPA) and securing the system against breaches are critical.
#
# Breaches or misuse of personal data could damage trust in the system and lead to legal consequences.
#
# Bias and Fairness in Recommendations:
#
# The recommendation system could unintentionally favor certain demographics or financial profiles, excluding disadvantaged groups.
#
# To mitigate this, the system must be audited regularly to ensure fairness, and algorithms should be adjusted to avoid discrimination or undue favoritism.**
